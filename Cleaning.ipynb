# %%
import pandas as pd
import re

# Load the dataset
df = pd.read_csv('tweets.csv')

# Define a function to clean the text data
def clean_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'#\w+', '', text)
    #Remove @
    text = re.sub(r'@\w+', '', text)
    # Remove URLs
    text = re.sub(r'http\S+|www\.\S+', '', text)
    # Remove extra whitespaces
    text = text.strip()
    # Remove 'rt :' (with or without spaces around the colon)
    text = re.sub(r'\brt\s*:\s*', '', text, flags=re.IGNORECASE)
    # Remove \r\n (line breaks)
    text = re.sub(r'\r\n', ' ', text)
    # Remove Unicode placeholders like <u+...>
    text = re.sub(r'<u\+\w+>', '', text)
    # Remove all exclamation marks
    text = text.replace('!', '')
    # Remove all question marks
    text = text.replace('?', '')
    # Remove specific unwanted characters
    text = re.sub(r'<u\+>', '', text)  # Remove <u+>
    text = re.sub(r'[©\':.,|]', '', text)  # Remove :, ', ., ,, |, and ©
    # Remove extra whitespaces caused by the cleanup
    text = re.sub(r'\s+', ' ', text).strip()
    return text


# Apply the cleaning function to the 'text' column
df['clean_text'] = df['text'].apply(clean_text)

# Remove rows with missing values (if any)
df = df.dropna(subset=['clean_text'])

# Save the cleaned data to a new CSV file
df.to_csv('tweets_cleaned.csv', index=False)

print("Data cleaned and saved to 'tweets_cleaned.csv'.")
# Out:
# Data cleaned and saved to 'tweets_cleaned.csv'.

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'text', 'favorited', 'favoriteCount', 'replyToSN',
#        'created', 'truncated', 'replyToSID', 'id', 'replyToUID',
#        'statusSource', 'screenName', 'retweetCount', 'isRetweet', 'retweeted',
#        'longitude', 'latitude', 'clean_text'],
#       dtype='object')

# %%
import pandas as pd

# Specify the file path
file_path = 'tweets_cleaned.csv'

# Load the dataset
data = pd.read_csv(file_path)

# View the first few rows
data.head()
# Out:
#    Unnamed: 0  \
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#
#                                                                                                                    text  \
# 0                               RT @mrvelstan: literally nobody:\r\nme:\r\n\r\n#AvengersEndgame https://t.co/LR9kFwfD5c
# 1  RT @agntecarter: i’m emotional, sorry!!\r\n\r\n2014 x 2019\r\n#blackwidow\r\n#captainamerica https://t.co/xcwkCMw18w
# 2                              saving these bingo cards for tomorrow \r\n©\r\n #AvengersEndgame https://t.co/d6For0jwRb
# 3                                  RT @HelloBoon: Man these #AvengersEndgame ads are everywhere https://t.co/Q0lNf5eJsX
# 4                      RT @Marvel: We salute you, @ChrisEvans! #CaptainAmerica #AvengersEndgame https://t.co/VlPEpnXYgm
#
#    favorited  favoriteCount replyToSN          created  truncated  replyToSID  \
# 0      False              0       NaN  23/4/2019 10:43      False         NaN
# 1      False              0       NaN  23/4/2019 10:43      False         NaN
# 2      False              0       NaN  23/4/2019 10:43      False         NaN
# 3      False              0       NaN  23/4/2019 10:43      False         NaN
# 4      False              0       NaN  23/4/2019 10:43      False         NaN
#
#              id  replyToUID  \
# 0  1.120640e+18         NaN
# 1  1.120640e+18         NaN
# 2  1.120640e+18         NaN
# 3  1.120640e+18         NaN
# 4  1.120640e+18         NaN
#
#                                                                            statusSource  \
# 0  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 1    <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2    <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3    <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4    <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#     screenName  retweetCount  isRetweet  retweeted  longitude  latitude  \
# 0    DavidAc96           637       True      False        NaN       NaN
# 1      NRmalaa           302       True      False        NaN       NaN
# 2     jijitsuu             0      False      False        NaN       NaN
# 3     SahapunB         23781       True      False        NaN       NaN
# 4  stella22_97         13067       True      False        NaN       NaN
#
#                               clean_text
# 0                    literally nobody me
# 1                  i’m emotional sorry x
# 2  saving these bingo cards for tomorrow
# 3           man these ads are everywhere
# 4                          we salute you

# %%
# Adjust display option
pd.set_option('display.max_colwidth', None)

# View the first few rows with full text


data[['clean_text']].head(60)
# Out:
#                                                                                                                         clean_text
# 0                                                                                                              literally nobody me
# 1                                                                                                            i’m emotional sorry x
# 2                                                                                            saving these bingo cards for tomorrow
# 3                                                                                                     man these ads are everywhere
# 4                                                                                                                    we salute you
# 5                       the first non-spoiler critic reactions are here and nearly all are exceptionally positive with many prais…
# 6                                                                                                                    ready to rock
# 7                                                                                          we’re with him ‘til the end of the line
# 8                                                                                first reactions most emotional most epic mcu film
# 9                                                                                                     man these ads are everywhere
# 10                                                                                                 destiny has arrived josh brolin
# 11                                                                                                                   we salute you
# 12                                                                           scarlett johansson and brie larson will defeat thanos
# 13                                                                heyy yall please share these pics and make sure to use the tag …
# 14                                                 first and last public event of the original six together i’m not crying i swear
# 15                                   boy these two fuckers will beat the holy shit outta ours feelings this next helluva weekend …
# 16                                                                                                                   we salute you
# 17                                                                                         chris hemsworth with his wife @ premier
# 18                                                          this is it the final one like follow and comment for your chance to w…
# 19                                                                                                    man these ads are everywhere
# 20                                                                                               see all the stars at the premiere
# 21                                                                                   get ready for rt or like for a paytm surprise
# 22  honestly chris evans saying he cried six times and hemsworth saying he cried more than six times means that we’re all literal…
# 23                                                                                                                    born leaders
# 24                                                                                                the red carpet’s a-buzz with and
# 25                     we’re here at the world premiere of marvel studios in la follow along here and on our instagram stories fo…
# 26                  he came to the wrong avenger good luck getting information from this tight-lipped captain chris evans at the …
# 27                                                                         we’re in the endgame now—who’s watching on opening week
# 28                                                                                     still not emotionally prepared for tomorrow
# 29                      whatever it takes we are live from the world premiere of marvel studios keep watching for interviews with…
# 30                                                                                                                   what a marvel
# 31                    wait – did chris hemsworth just spill details on thor’s fate (we’re pretty sure this counts for something) …
# 32                                                                                                                   we salute you
# 33                                                                                   get ready for rt or like for a paytm surprise
# 34                                      scarlett johansson attends the world premiere of marvel studios’ in los angeles californi…
# 35                                man kicked my ass it was an epic conclusion to years of films it had laughs incredible action a…
# 36                                                                                                      i just i love this picture
# 37                                                                                              the beginning and the end of a era
# 38                                                                                                bricks hours one heroic set from
# 39                                                                                                    man these ads are everywhere
# 40                                                                               miley liam and chris hemsworth at the premiere of
# 41                                                      chris evans crashes an iron man reunion on the carpet marvel entertainment
# 42  honestly chris evans saying he cried six times and hemsworth saying he cried more than six times means that we’re all literal…
# 43                                                                                                                   we salute you
# 44                             while watching i laughed so loud i clapped with so much force and i cried so hard the movie exceed…
# 45                                                                                           wow i feel like crying it was amazing
# 46                             here’s your look at an exclusive poster from and get it when you purchase your marvel studios’ tic…
# 47                                                                                                    man these ads are everywhere
# 48                                                                                              elizabeth olsen bringing the magic
# 49                                                                                      steering clear of social media until i see
# 50                                                                                                    man these ads are everywhere
# 51                                                                                                    man these ads are everywhere
# 52                                                                                          black widow herself scarlett johansson
# 53                                                                                                                        is groot
# 54                                                          this is it the final one like follow and comment for your chance to w…
# 55                                             the cast stars in a mash-up to the tune of “we didn’t start the fire” by billy joel
# 56  honestly chris evans saying he cried six times and hemsworth saying he cried more than six times means that we’re all literal…
# 57                                                                                                        alan master of the rod …
# 58                                                                              the stars of begin to arrive at the world premiere
# 59                                                                                          black widow herself scarlett johansson

# %%
# Adjust display option
pd.set_option('display.max_colwidth', None)

# View the first few rows with full text


data[['clean_text']].tail(60)
# Out:
#                                                                                                                            clean_text
# 14940                                                                                                    man these ads are everywhere
# 14941  honestly chris evans saying he cried six times and hemsworth saying he cried more than six times means that we’re all literal…
# 14942                                    let’s bring our a game on &amp; get this one right releases this friday book your tickets on
# 14943                                                                                         we’re with him ‘til the end of the line
# 14944                                                                                                    man these ads are everywhere
# 14945                                              comic con they were first seen as the avengers the last time they will be together
# 14946                                                                                                                   we salute you
# 14947                                                                                                                   we salute you
# 14948                                              as we get closer to the we will do to make you watch the great grand finale rt an…
# 14949                     both scarlett and brie are with the infinity stones as rings but until now just them this means something …
# 14950                                                                                                    man these ads are everywhere
# 14951                                                                                          black widow herself scarlett johansson
# 14952                                         one taught me love one taught me patience one taught me pain ones gonna fucking kill me
# 14953                               here’s your look at an exclusive poster from and get it when you purchase your marvel studios’ t…
# 14954                                                                                                       with a smashisng entrance
# 14955                                                                                                                   hits the mark
# 14956                                                                                                             "there was an idea"
# 14957                                                                                                            welcome to the party
# 14958                                                                                                                   we salute you
# 14959                                                                                      a) eitri made the made the thanos gauntlet
# 14960                                                      chris evans crashes an iron man reunion on the carpet marvel entertainment
# 14961                                                                                   get ready for rt or like for a paytm surprise
# 14962                                                                                                        tomorrow will be our day
# 14963                                                                                                    man these ads are everywhere
# 14964                        is epic emotional and the biggest blockbuser from marvel you guys dont even know what you are in for it…
# 14965                                                                                   get ready for rt or like for a paytm surprise
# 14966                                                                                                  part of the journey is the end
# 14967                                                                                           wow i feel like crying it was amazing
# 14968                           wow is staggering it’s surprising in ways i never saw coming and satisfying in ways i didn’t realize…
# 14969                                                                         miley on the carpet of the premiere credits gettyimages
# 14970                                                                                               sebastian stan stans how we doing
# 14971                                                                                           reason number why to stan brie larson
# 14972                                                                                                 destiny has arrived josh brolin
# 14973                                                                                                     eternal love for her please
# 14974                                                                                                          with a magical arrival
# 14975                                                                                                                       soft porn
# 14976                                                                        brie larson with some inspired jewellery at the premiere
# 14977                                                                                        excited much for tomorrow watching at am
# 14978                                                            rt &amp; follow for the chance to win a exclusive -inch thanos pop …
# 14979                                                                              im like this today only replace santa with endgame
# 14980                                                                                                                     after party
# 14981                                                                          natalie has attended the premiere of avengers end game
# 14982                                                         not long now tomorrow’s double bill of infinity war followed by endgame
# 14983                                                                                          blue has never looked this good before
# 14984                                                                                                    man these ads are everywhere
# 14985                              some of the avengers main men - thor () captain america () ant-man (paul rudd) &amp; bruce banner…
# 14986                                                                                          black widow herself scarlett johansson
# 14987                                                                                                    man these ads are everywhere
# 14988                                                                                                                   we salute you
# 14989                                                                                                         noted and agreed team …
# 14990                                                                               elizabeth olsen looks absolutely stunning tonight
# 14991                                                                                           reason number why to stan brie larson
# 14992                                                                                              elizabeth olsen bringing the magic
# 14993                                                                                                   ooooooh you guys it’s so good
# 14994                                                                              we will take the fight back to him and we will win
# 14995                                                                     first time last time with the avengers with the avengers #…
# 14996                       the cast has seen a lot of each other over the years so we figured they could handle a game of name the …
# 14997                                                kindly announce the approximate timings for imax tickets booking for endgame pls
# 14998                                                                                                                   we salute you
# 14999                                                                                                            welcome to the party
